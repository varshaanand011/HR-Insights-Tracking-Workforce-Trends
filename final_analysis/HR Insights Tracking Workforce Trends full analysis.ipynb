# %% [markdown]
# <h1 style="text-align:center; font-size:36px;">
# HR Insights: Tracking Workforce Trends</h1>

# %% [markdown]
# ***Project Overview***
#
#
#
# ***```Domain```***:Human Resources Analytics / Workforce Analytics

# %% [markdown]
# ***```Objective```***
#
# The objective of this project is to analyze employee demographic characteristics, job roles, compensation structure, work experience, and satisfaction levels to identify the key factors influencing employee attrition. The analysis focuses on understanding behavioral and organizational patterns that distinguish employees who leave the organization from those who remain, supporting data-driven retention strategies.

# %% [markdown]
# ***```Business Problem```***:
#
# Employee turnover poses a significant challenge for organizations. High attrition rates lead to increased recruitment and training costs, loss of experienced talent, reduced productivity, and disruptions in team stability. Many organizations lack clear insights into the underlying factors that contribute to employee dissatisfaction and voluntary exits.
#
# - By identifying the drivers of employee attrition,
#
#   organizations can:
#
# - Improve employee engagement and job satisfaction
#
# - Design effective and targeted retention strategies
#
# - Optimize compensation, career progression, and work-life balance initiatives
#
# - Reduce operational costs associated with frequent hiring
#
# - This project applies exploratory data analysis (EDA) techniques to uncover patterns and trends in employee data that explain attrition behavior and support proactive HR decision-making.

# %% [markdown]
# ***```Dataset Description```***:
#
# The analysis is conducted using the HR Insights: Tracking Workforce Trends Dataset, which contains detailed employee-level data from a corporate environment.
#
#  Key Characteristics of the Dataset:
#
# - Total Records: 23530
#
# - Total Features: 35
#
# - Data Type: Structured, tabular dataset
#
# - Target Variable: Attrition (Yes / No)

# %% [markdown]
# <h1 style="font-size:22px;">PHASE 1: DATA LOADING & INITIAL OVERVIEW</h1>
#
#
# ```EXECUTIVE SUMMARY```
#
# Data loading and initial overview is used to import the dataset and understand its basic structure, size, and variables. This phase helps identify data types, missing values, and overall data composition, providing a foundation for further cleaning and analysis.

# %% [markdown]
# ```PHASE 1: DATA LOADING & INITIAL OVERVIEW – SUMMARY```
#
# This phase focuses on loading the HR dataset and understanding its structure and basic characteristics.
#
# Using:
#
# - Data loading techniques
#
# - Dataset shape and dimension checks
#
# - Data type inspection
#
# - Initial data preview (head & tail)
#
# - Basic descriptive statistics
#
# this phase provides a high-level understanding of the dataset and identifies potential data quality issues to guide further cleaning and analysis.

# %% [markdown]
# >STEP 1: IMPORT NECESSARY LIBRARIES
#
# Objective: Load essential Python libraries required for data handling and inspection.

# %%
import pandas as pd

# %%
import numpy as np

# %% [markdown]
# >STEP 2: LOAD THE DATASET

# %% [markdown]
# ***2.1 Data Source and Loading***
#
# Data Source:
#
# The dataset used in this analysis is the HR Insights: Tracking Workforce Trends Dataset (extended version) available on Kaggle.
#
# ***Source Link***:
# https://www.kaggle.com/datasets/dgokeeffe/ibm-hr-wmore-rows
#
# This dataset contains HR records for employees across various departments and roles, with a focus on understanding attrition patterns.
#
# ***Dataset Description***
#
# HR Insights: Tracking Workforce Trends dataset includes detailed information for a large number of employees, capturing demographic, job, compensation, performance, and engagement-related attributes. It is widely used for analyzing factors that contribute to employee attrition.
#
# ***Loading Objectives***
#
# - The goal of this step is to import the dataset and perform an initial overview to understand its structure before detailed analysis.
#
#   The objectives include:
#
# - Identifying the total number of records (rows) — representing employees in the dataset
#
# - Determining the total number of features (columns) — representing employee attributes
#
# - Reviewing column names and data types
#
# - Assessing the general completeness and structure of the dataset

# %%
data = pd.read_csv("IBM_HR_Data.csv", low_memory=False)

# %% [markdown]
# >STEP 3: DATA TYPE INSPECTION
#
# Objective: Understand the data types and identify potential issues

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23530 entries, 0 to 23529
# Data columns (total 37 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       23527 non-null  float64
#  1   Attrition                 23517 non-null  object
#  2   BusinessTravel            23522 non-null  object
#  3   DailyRate                 23519 non-null  float64
#  4   Department                23519 non-null  object
#  5   DistanceFromHome          23521 non-null  float64
#  6   Education                 23518 non-null  float64
#  7   EducationField            23521 non-null  object
#  8   EmployeeCount             23525 non-null  float64
#  9   EmployeeNumber            23530 non-null  object
#  10  Application ID            23527 non-null  object
#  11  EnvironmentSatisfaction   23521 non-null  float64
#  12  Gender                    23520 non-null  object
# ...

# %% [markdown]
# Insight:
#
# - Reveals column data types
# - Highlights missing values
# - Identifies columns requiring type conversion

# %% [markdown]
# >STEP 4: DATASET DIMENSIONS
#
# Objective: Identify the size of the dataset.

# %%
print("shape:",data.shape)
# Out:
# shape: (23530, 37)

# %% [markdown]
# Insight:
#
# - Displays the total number of rows and columns
# - Helps assess whether the dataset meets minimum project requirements

# %% [markdown]
# >STEP 5: PREVIEW DATA RECORDS
#
# Objective: Examine sample records to understand variable content.

# %%
display(data.head(5))
# Out:
#     Age              Attrition BusinessTravel  DailyRate       Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0            Sales
# 1  37.0  Voluntary Resignation  Travel_Rarely      807.0  Human Resources
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0            Sales
# 3  37.0  Voluntary Resignation  Travel_Rarely      807.0  Human Resources
# 4  37.0  Voluntary Resignation  Travel_Rarely      807.0  Human Resources
#
#    DistanceFromHome  Education   EducationField  EmployeeCount EmployeeNumber  \
# 0               1.0        2.0    Life Sciences            1.0              1
# 1               6.0        4.0  Human Resources            1.0              1
# 2               1.0        2.0    Life Sciences            1.0              1
# 3               6.0        4.0        Marketing            1.0              4
# 4               6.0        4.0  Human Resources            1.0              5
#
# ...

# %% [markdown]
# Insight:
#
# - Confirms correct data loading
# - Helps spot obvious anomalies or formatting issues

# %% [markdown]
# >STEP 6: INITIAL STATISTICAL OVERVIEW
#
# Objective: Generate basic descriptive statistics.

# %%
display(data.describe(include='all'))
# Out:
#                  Age         Attrition BusinessTravel     DailyRate  \
# count   23527.000000             23517          23522  23519.000000
# unique           NaN                 3              3           NaN
# top              NaN  Current employee  Travel_Rarely           NaN
# freq             NaN             19712          16700           NaN
# mean       36.914354               NaN            NaN    802.168375
# std         9.130563               NaN            NaN    403.198769
# min        18.000000               NaN            NaN    102.000000
# 25%        30.000000               NaN            NaN    465.000000
# 50%        36.000000               NaN            NaN    802.000000
# 75%        43.000000               NaN            NaN   1157.000000
# max        60.000000               NaN            NaN   1499.000000
#
#                     Department  DistanceFromHome     Education EducationField  \
# ...

# %% [markdown]
# Insight:
#
# - Summarizes numerical and categorical variables
# - Identifies outliers, ranges, and distributions
# - Highlights missing or unusual values

# %% [markdown]
# <h1 style="font-size:22px;">PHASE 2: DATA CLEANING & PRE-PROCESSING</h1>
#
#
# Data cleaning and preprocessing is used to improve data quality by handling missing values, correcting inconsistencies, removing duplicates, and validating logical relationships. This process ensures the dataset is accurate, consistent, and ready for reliable exploratory data analysis and modeling.

# %% [markdown]
# ```SUMMARY```
#
# This phase prepares the dataset for analysis by improving data quality and consistency.
#
# Using:
#
# - Missing value detection and treatment
# - Duplicate record checks
# - Data type correction
# - Logical relationship validation
# - Data consistency and integrity checks
# - Outlier and anomaly identification
# - Feature standardization and formatting
#
# this phase ensures the dataset is accurate, consistent, and analysis-ready for exploratory data analysis and visualization.

# %% [markdown]
# > STEP 1: MISSING VALUE ANALYSIS

# %% [markdown]
# Objective: Identify and handle missing or null values to avoid biased analysis.
#
# Actions Performed:
#
# - Checked missing values across all columns
# - Identified numerical and categorical columns with missing data
# - Evaluated appropriate handling strategies based on column type

# %%
data.isnull().sum()
# Out:
# Age                          3
# Attrition                   13
# BusinessTravel               8
# DailyRate                   11
# Department                  11
# DistanceFromHome             9
# Education                   12
# EducationField               9
# EmployeeCount                5
# EmployeeNumber               0
# Application ID               3
# EnvironmentSatisfaction      9
# Gender                      10
# HourlyRate                   9
# JobInvolvement               9
# JobLevel                     7
# JobRole                      9
# JobSatisfaction              9
# MaritalStatus               11
# MonthlyIncome               14
# MonthlyRate                 11
# NumCompaniesWorked           9
# Over18                      10
# OverTime                    12
# PercentSalaryHike           14
# PerformanceRating           10
# RelationshipSatisfaction     8
# StandardHours               10
# StockOptionLevel             9
# TotalWorkingYears            8
# ...

# %% [markdown]
# >STEP 2: DUPLICATE RECORD CHECK
#
# Objective: Ensure each employee record is unique.
#
# - Actions Performed:
# - Checked for duplicate rows in the dataset
# - Removed duplicate records where detected

# %%
print(data.duplicated().sum())
# Out:
# 14

# %%
data=data.drop_duplicates()
print(data.duplicated().sum())
# Out:
# 0

# %% [markdown]
# Actions Performed:
#
# - Checked for duplicate rows
# - Removed duplicate records where detected
#
# Outcome:
# - Dataset now contains unique employee entries only

# %% [markdown]
# >STEP 3: REMOVE IRRELEVANT / CONSTANT COLUMNS
#
# Objective:
# - Remove columns that do not contribute meaningful information to analysis.

# %%
cols_to_drop=['Education','EmployeeCount','EmployeeNumber','Over18','StandardHours']
data.drop(columns=[i for i in cols_to_drop if i in data.columns],inplace=True)
print('\n Remaining columns:',data.columns.tolist())
# Out:
#  Remaining columns: ['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department', 'DistanceFromHome', 'EducationField', 'Application ID', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime', 'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager', 'Employee Source']

# %% [markdown]
# Actions Performed:
#
# - Identified constant or near-constant columns (single unique value)
# - Removed irrelevant identifiers and non-informative features
#
# Outcome:
# - Dataset contains only relevant and informative features.

# %% [markdown]
# DISPLAYING SHAPE AFTER REMOVAL

# %%
print("Remaining Data shape:",data.shape)
# Out:
# Remaining Data shape: (23516, 32)

# %% [markdown]
# >STEP 4 : DATA TYPE CORRECTION
#
# Objective:
# - Ensure columns have appropriate and consistent data types.

# %%
for col in data.columns:
    if data[col].dtype=='object':
       try:
           data[col]=pd.to_numeric(data[col])
       except:
           pass
data.dtypes
# Out:
# Age                         float64
# Attrition                    object
# BusinessTravel               object
# DailyRate                   float64
# Department                   object
# DistanceFromHome            float64
# EducationField               object
# Application ID               object
# EnvironmentSatisfaction     float64
# Gender                       object
# HourlyRate                  float64
# JobInvolvement              float64
# JobLevel                    float64
# JobRole                      object
# JobSatisfaction             float64
# MaritalStatus                object
# MonthlyIncome               float64
# MonthlyRate                 float64
# NumCompaniesWorked          float64
# OverTime                     object
# PercentSalaryHike           float64
# PerformanceRating           float64
# RelationshipSatisfaction    float64
# StockOptionLevel            float64
# TotalWorkingYears           float64
# TrainingTimesLastYear       float64
# ...

# %% [markdown]
# Actions Performed:
# - Converted numeric fields stored as text into numeric format Ensured categorical variables were correctly stored as object types Verified date-related fields (if any)
#
# Outcome:
# -  All columns now have correct and analysis-ready data types

# %% [markdown]
# >STEP 5: FIX MISSING VALUES
#
# Objective:
# - Handle missing values to ensure completeness and avoid bias in analysis.

# %%
num_cols = data.select_dtypes(include=['int64','float64']).columns
for col in num_cols:
    data[col] = data[col].fillna(data[col].median())
    
cat_cols = data.select_dtypes(include=['object']).columns
for col in cat_cols:
    data[col] = data[col].replace("Unknown", data[col].mode()[0])
    data[col] = data[col].fillna(data[col].mode()[0])
data.isna().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# EducationField              0
# Application ID              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# ...

# %% [markdown]
# Actions Performed:
#
# - Filled missing values in numerical columns using the median, preserving data distribution
# - Filled missing values in categorical columns using the value "Unknown" to maintain category consistency
#
# Outcome:
# - The dataset contains no missing values in key analytical columns and is fully prepared for further analysis.

# %% [markdown]
# > DATA VALIDATION

# %% [markdown]
# >STEP 6: CHECK FOR NEGATIVE NUMBERS
#
# Objective:
# Validate that numerical values fall within logical ranges.

# %%
numeric_cols=data.select_dtypes(include=['float64','int64']).columns
negatives=(data[numeric_cols] <0).sum()
negatives[negatives > 0]
# Out:
# Series([], dtype: int64)

# %% [markdown]
# Validations Performed:
#
# - Checked for negative values in:
# - Age
# - Monthly Income
# - Years at Company
# - Years with Current Manager
#
# Corrections Applied:
# - Replaced or removed invalid negative values where necessary

# %%
print(negatives)
# Out:
# Age                         0
# DailyRate                   0
# DistanceFromHome            0
# EnvironmentSatisfaction     0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobSatisfaction             0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# YearsWithCurrManager        0
# dtype: int64

# %% [markdown]
# >STEP 7: DATA CONSISTENCY & LOGICAL VALIDATION
#
# Objective:
# - Ensure logical consistency between related variables.

# %%
data[data['Age']< 18]
data[data['Age'] > 80]
invalid_age = data[(data['Age'] < 18) | (data['Age'] > 60)]
invalid_age
# Out:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, EducationField, Application ID, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Employee Source]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# Validations Performed:
# - THIS CHECK ENSURE NO EMPLOYEE IS YOUNGER THAN 18 & CAN ALSO CHECK IF AGE IS USUALLY HIGH (Eg.>60).

# %% [markdown]
# >STEP 7.1: DATA INCONSISTENCY
#
# Objective:
# - MONTHLY INCOME MUST BE GREATER THAN 0
# - MONTHLY INCOME MUST BE POSITIVE, AND NO EMPLOYEE SHOULD HAVE INVALID OR IMPOSSIBLE VALUES.

# %%
data['MonthlyIncome'] = pd.to_numeric(data['MonthlyIncome'])
print("\nEmployees with MonthlyIncome less than or equal to 0:")
print(data[data['MonthlyIncome'] <= 0])
# Out:
# Employees with MonthlyIncome less than or equal to 0:
# Empty DataFrame
# Columns: [Age, Attrition, BusinessTravel, DailyRate, Department, DistanceFromHome, EducationField, Application ID, EnvironmentSatisfaction, Gender, HourlyRate, JobInvolvement, JobLevel, JobRole, JobSatisfaction, MaritalStatus, MonthlyIncome, MonthlyRate, NumCompaniesWorked, OverTime, PercentSalaryHike, PerformanceRating, RelationshipSatisfaction, StockOptionLevel, TotalWorkingYears, TrainingTimesLastYear, WorkLifeBalance, YearsAtCompany, YearsInCurrentRole, YearsSinceLastPromotion, YearsWithCurrManager, Employee Source]
# Index: []
#
# [0 rows x 32 columns]

# %% [markdown]
# Outcome:
# - The dataset contain zero employees with MonthlyIncome less than or equal to zero

# %% [markdown]
# >STEP 8: DERIVED COLUMN CREATION
#
# Objective:
# - Create new features to support better analysis.
#
# Derived Features Created:
#
# - Age groups
# - Tenure categories
# - Attrition flags (binary indicators)
#
# Outcome:
# - Enhanced analytical depth and improved interpretability.

# %% [markdown]
# *TENURE GROUP*
# - GROUPS TOTAL WORKING YEARS INTO MEANINGFUL RANGES
# - CATEGORIZES EMPLOYEES INTO GROUP BASED ON YEARS OF EXPERIENCE

# %%
data['TenureGroup'] = pd.cut(
    data['TotalWorkingYears'],
    bins=[-1, 2, 5, 10, 20, 60],
    labels=['<3', '3-5', '6-10', '11-20', '20+']
)

# %%
data['TenureGroup']
# Out:
# 0        6-10
# 1        6-10
# 2        6-10
# 3        6-10
# 4        6-10
#          ...
# 23525    6-10
# 23526     3-5
# 23527     20+
# 23528    6-10
# 23529    6-10
# Name: TenureGroup, Length: 23516, dtype: category
# Categories (5, object): ['<3' < '3-5' < '6-10' < '11-20' < '20+']

# %% [markdown]
# *AGE GROUPING*
# - CREATES SEGMENTS EMPLOYEES BY AGE.

# %%
data['Age_Group'] = pd.cut(
    data['Age'],
    bins=[17, 25, 35, 45, 55, 70],
    labels=["18-25", "26-35", "36-45", "46-55", "55+"]
)

# %%
data['Age_Group']
# Out:
# 0        36-45
# 1        36-45
# 2        36-45
# 3        36-45
# 4        36-45
#          ...
# 23525    26-35
# 23526    36-45
# 23527    46-55
# 23528    26-35
# 23529    18-25
# Name: Age_Group, Length: 23516, dtype: category
# Categories (5, object): ['18-25' < '26-35' < '36-45' < '46-55' < '55+']

# %% [markdown]
# *CONVERTS ATTRITION INTO A BINARY VALUE (1 = LEFT, 0 = STAYED).*

# %%
data['AttritionFlag'] = data['Attrition'].map({
    'Voluntary Resignation': 1,
    'Current employee': 0
})

# %%
data['AttritionFlag']
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        1.0
# 4        1.0
#         ...
# 23525    0.0
# 23526    0.0
# 23527    0.0
# 23528    0.0
# 23529    1.0
# Name: AttritionFlag, Length: 23516, dtype: float64

# %% [markdown]
# >STEP 9: FILTERING & AGGREGATING DATA
#
# Objective:
# - Prepare summarized datasets for EDA and visualization.
#
# Actions Performed:
#
# - Used filtering to isolate key employee groups
# - Created aggregated metrics (mean income, count of employees by dept , max age)

# %% [markdown]
# >FILTERING
#
# objective:
# - FILTERS EMPLOYEES WHO LEFT FROM THE COMPANY

# %%
left_employees = data[data['Attrition']=='Voluntary Resignation']
left_employees.head()
# Out:
#     Age              Attrition BusinessTravel  DailyRate       Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0            Sales
# 1  37.0  Voluntary Resignation  Travel_Rarely      807.0  Human Resources
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0            Sales
# 3  37.0  Voluntary Resignation  Travel_Rarely      807.0  Human Resources
# 4  37.0  Voluntary Resignation  Travel_Rarely      807.0  Human Resources
#
#    DistanceFromHome   EducationField Application ID  EnvironmentSatisfaction  \
# 0               1.0    Life Sciences         123456                      2.0
# 1               6.0  Human Resources         123457                      1.0
# 2               1.0    Life Sciences         123458                      2.0
# 3               6.0        Marketing         123459                      1.0
# 4               6.0  Human Resources         123460                      1.0
#
# ...

# %%
print(len(left_employees))
# Out:
# 3698

# %% [markdown]
# objective:
# - FILTERS ACTIVE EMPLOYEES STILL WORKING IN THE COMPANY

# %%
current_employees = data[data['Attrition'] == "Current employee"]
current_employees.head()
# Out:
#      Age         Attrition     BusinessTravel  DailyRate  \
# 18  49.0  Current employee  Travel_Frequently      279.0
# 19  59.0  Current employee         Non-Travel     1420.0
# 20  59.0  Current employee         Non-Travel     1420.0
# 21  49.0  Current employee  Travel_Frequently      279.0
# 22  49.0  Current employee  Travel_Frequently      279.0
#
#                 Department  DistanceFromHome   EducationField Application ID  \
# 18  Research & Development               8.0    Life Sciences         123474
# 19         Human Resources               2.0  Human Resources         123475
# 20         Human Resources               2.0    Life Sciences         123476
# 21  Research & Development               8.0        Marketing         123477
# 22  Research & Development               8.0    Life Sciences         123478
#
#     EnvironmentSatisfaction Gender  ...  TrainingTimesLastYear  \
# 18                      3.0   Male  ...                    3.0
# ...

# %%
len(current_employees)
# Out:
# 19722

# %% [markdown]
# objective:
# - DISPLAYS ALL EMPLOYEES BELONGING TO THE SALES DEPARTMENT

# %%
sales_emp=data[data['Department']=='Sales']
sales_emp.head()
# Out:
#     Age              Attrition BusinessTravel  DailyRate Department  \
# 0  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 2  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 6  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 7  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
# 8  41.0  Voluntary Resignation  Travel_Rarely     1102.0      Sales
#
#    DistanceFromHome EducationField Application ID  EnvironmentSatisfaction  \
# 0               1.0  Life Sciences         123456                      2.0
# 2               1.0  Life Sciences         123458                      2.0
# 6               1.0  Life Sciences         123462                      2.0
# 7               1.0  Life Sciences         123463                      2.0
# 8               1.0  Life Sciences         123464                      2.0
#
#    Gender  ...  TrainingTimesLastYear  WorkLifeBalance  YearsAtCompany  \
# ...

# %% [markdown]
# >AGGREGATION

# %% [markdown]
# objective:
# - AVERAGE MONTHLY INCOME BY DEPARTMENT

# %%
avg_sal_dept=data.groupby('Department')['MonthlyIncome'].mean()

# %% [markdown]
# CALCULATES THE AVERAGE SALARY FOR EACH DEPARTMENT

# %%
avg_sal_dept.head()
# Out:
# Department
# Human Resources           6442.313300
# Research & Development    6357.825441
# Sales                     6824.213067
# Name: MonthlyIncome, dtype: float64

# %% [markdown]
# objective:
# - COUNT OF EMPLOYEES IN EACH DEPARTMENT

# %%
count_emp=data['Department'].value_counts()

# %% [markdown]
# objective:
# - DISPLAYS NUMBER OF EMPLOYEES WORKING IN EACH DEPARTMENT

# %%
count_emp.head()
# Out:
# Department
# Research & Development    15353
# Sales                      7148
# Human Resources            1015
# Name: count, dtype: int64

# %% [markdown]
# objective:
# - MAXIMUM AGE OF EMPLOYEES

# %%
max_age=data['Age'].max()

# %%
max_age
# Out:
# 60.0

# %% [markdown]
# >STEP 10: EXPORT CLEANED DATASET
#
# Objective:
# - Save the cleaned and validated HR dataset for further exploratory data analysis and modeling.

# %%
data.to_csv("IBM_HR_CLEANED.csv", index=False)

# %% [markdown]
# Action Performed:
#
# - Exported the final cleaned dataset to a CSV file using:
#
# Outcome:
# - The cleaned dataset is successfully stored as IBM_HR_CLEANED.csv, ensuring reproducibility and easy reuse for EDA and future analysis phases.

# %% [markdown]
# <h1 style="font-size:22px;">PHASE 3: EDA & VISUALIZATION.</h1>
#
# ```EDA OVERVIEW```
#
# Exploratory Data Analysis (EDA) is used to analyze and summarize the dataset to identify patterns, trends, relationships, and anomalies using statistical measures and visualizations. This process helps in understanding the structure of the data and supports data-driven decision-making.

# %% [markdown]
# ``` SUMMARY```
#
# This exploratory data analysis examines employee demographics, compensation, job satisfaction, and attrition patterns within the organization.
#
# Using
# - univariate
# - bivariate
# - multivariate analysis techniques
# - descriptive statistics
# - groupby operations
# - pivot tables
# - visualizations.
#
# The analysis uncovers key workforce trends and factors influencing employee attrition, supporting data-driven HR decision-makingby identifying key factors related to retention and employee performance.

# %% [markdown]
# >STEP 1: IMPORT NECESSARY LIBRARIES
#
# - Objective:
#
#    - Load essential Python libraries for data manipulation and import the HR dataset for analysis..

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
data =pd.read_csv("IBM_HR_CLEANED.csv")

# %% [markdown]
# >STEP 2: STATISTICAL SUMMARY
#
# Objective: Generate descriptive statistics to support visual findings.

# %%
data.describe(include='all')
# Out:
#                  Age         Attrition BusinessTravel     DailyRate  \
# count   23516.000000             23516          23516  23516.000000
# unique           NaN                 3              3           NaN
# top              NaN  Current employee  Travel_Rarely           NaN
# freq             NaN             19722          16694           NaN
# mean       36.917588               NaN            NaN    802.087302
# std         9.129708               NaN            NaN    403.118562
# min        18.000000               NaN            NaN    102.000000
# 25%        30.000000               NaN            NaN    465.000000
# 50%        36.000000               NaN            NaN    802.000000
# 75%        43.000000               NaN            NaN   1157.000000
# max        60.000000               NaN            NaN   1499.000000
#
#                     Department  DistanceFromHome EducationField  \
# count                    23516      23516.000000          23516
# ...

# %% [markdown]
# > STEP 3: ***UNIVARIATE ANALYSIS – UNDERSTANDING DATA DISTRIBUTION***
#
# ```SUMMARY```
# - Analyzes each variable individually to understand employee distribution and characteristics.
#
# Objective:
#    - Analyze individual variables to understand employee composition, satisfaction levels, and income distribution.

# %% [markdown]
# > VISUALIZATION 1: ATTRITION DISTRIBUTION – BAR PLOT
#
#  Objective:
# - Identify overall employee attrition count.

# %%
data['Attrition'].value_counts().plot(kind='bar',color=['green','red'])
plt.title('EMPLOYEE ATTRITION COUNT')
plt.xlabel('ATTRITION STATUS')
plt.xticks(rotation=0)
plt.ylabel('EMPLOYEE COUNT')
plt.show()

# %% [markdown]
# Action Performed:
# - Plotted a bar chart of Attrition values.
#
# Outcome:
# - Clear visualization showing the number of employees who left vs stayed.

# %% [markdown]
# >Visual 2: Age Distribution – Histogram
#
# Objective:
# - Understand age distribution of employees.

# %%
plt.hist(data['Age'],bins=15,color='crimson',edgecolor='black')
plt.title('AGE DISTRIBUTION')
plt.xlabel('AGE')
plt.ylabel('FREQUENCY')
plt.show()

# %% [markdown]
# Action Performed:
# - Plotted histogram of Age with bins and frequency.
#
# Outcome:
# - Shows age demographics and concentration of employees.

# %% [markdown]
# >Visual 3: EMPLOYEE DISTRIBUTION BY SOURCE – PIE CHART
#
# Objective:
#
# - To understand the proportion of employees hired through different sources such as referral, campus, job portals, etc.

# %%
data['Employee Source'].value_counts().plot(kind='pie', autopct='%1.1f%%')
plt.title("EMPLOYEE DISTRIBUTION BY SOURCE")
plt.ylabel("")
plt.show()

# %% [markdown]
# Action Performed:
# - A pie chart is created using the Employee Source column to display the percentage contribution of each hiring source to the total workforce.
# The autopct parameter is used to show percentage values clearly.
#
# Outcome / Insight:
#
# - The chart clearly shows which recruitment source contributes the most employees and which sources are under-utilized, helping the organization evaluate the effectiveness of hiring channels.

# %% [markdown]
# >Visual 4: Monthly Income Distribution – Histogram
#
# Objective:
# - Explore monthly income variation among employees.

# %%
plt.hist(data['MonthlyIncome'],bins=20,color='purple',edgecolor='black')
plt.title('MONTHLY INCOME DISTRIBUTION')
plt.xlabel('MONTHLY INCOME')
plt.ylabel('FREQUENCY')
plt.show()

# %% [markdown]
# Action Performed:
# - Plotted histogram for MonthlyIncome.
#
# Outcome:
# - Identifies income ranges and majority employee earning levels.

# %% [markdown]
# >Visual 5: Job Satisfaction – Bar Plot
#
# Objective:
# - Analyze employee job satisfaction levels.

# %%
data["JobSatisfaction"].value_counts().sort_index().plot(kind='bar',color='rosybrown')
plt.title('JOB SATISFACTION LEVELS')
plt.xlabel('SATISFACTION LEVEL')
plt.xticks(rotation=0)
plt.ylabel('EMPLOYEE COUNT')
plt.show()

# %% [markdown]
# Action Performed:
#  - Counted and plotted JobSatisfaction levels.
#
# Outcome:
#  - Provides insight into employee satisfaction distribution

# %% [markdown]
# >Visual 6: Work Life Balance – Bar Plot
#
# Objective:
# - Examine work-life balance ratings among employees.

# %%
data['WorkLifeBalance'].value_counts().sort_index().plot(kind='bar',color='steelblue')
plt.title('WORK LIFE BALANCE LEVELS')
plt.xlabel('BALANCE LEVEL')
plt.ylabel('EMPLOYEE COUNT')
plt.show()

# %% [markdown]
# Action Performed:
# - Plotted counts of WorkLifeBalance values.
#
# Outcome:
# - Highlights balance satisfaction and potential stress points.

# %% [markdown]
# >STEP 4: ***BIVARIATE ANALYSIS – UNDERSTANDING DATA DISTRIBUTION***
#
# ```SUMMARY```
# - Examines the relationship between two variables to identify factors influencing attrition.
#
# Objective:
# - Examine relationships between employee attributes and attrition.

# %% [markdown]
# >Visual 7: Attrition by Gender
#
# Objective:
# - Assess gender-based attrition differences.

# %%
sns.countplot(x='Gender',hue='Attrition',data=data)
plt.title('ATTRITION BY GENDER')
plt.xlabel('GENDER')
plt.ylabel('ATTRITION STATUS')
plt.legend(title='ATTRITION STATUS')
plt.show()

# %% [markdown]
# >Visual 8: Attrition by Department - point plot
#
# Objective:
# - Understand attrition trends across departments.

# %%
sns.pointplot(x='Department',y='AttritionFlag',hue='Gender',data=data)
plt.ylabel("ATTRITION RATE")
plt.title("ATTRITION RATE BY EMPLOYEE SOURCE")
plt.legend(title="GENDER")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Action Performed:
# - Counted attrition by Department.
#
# Outcome:
# - Highlights departments with higher employee turnover.

# %% [markdown]
# >Visual 9: Age vs Monthly Income – Scatter Plot
#
# Objective:
# - Explore relationship between age and income.

# %%
plt.scatter(data['Age'],data['MonthlyIncome'],color='darkviolet',alpha=0.6)
plt.title('AGE VS MONTHLY INCOME')
plt.xlabel("AGE")
plt.ylabel('MONTHLY INCOME')
plt.show()

# %% [markdown]
# Action Performed:
# - Scatter plot of Age vs MonthlyIncome.
#
# Outcome:
# - Shows income trends across age groups.

# %% [markdown]
# >Visual 10: Income by Attrition -Violin Plot (Seaborn)
#
# Objective:
# - Compare income distribution by attrition.

# %%
sns.violinplot(x='Attrition', y='MonthlyIncome', data=data)
plt.title("INCOME DISTRIBUTION BY ATTRITION")
plt.show()

# %% [markdown]
# Action Performed:
# - Used Seaborn’s violinplot for Attrition vs MonthlyIncome.
#
# Outcome:
# - Shows distribution shape and spread.

# %% [markdown]
# Visual 11: Monthly Income by Attrition – Box Plot
#
# Objective:
# - Compare income distribution by attrition status.

# %%
sns.boxplot(x='Attrition', y='MonthlyIncome', data=data)
plt.title("MONTHLY INCOME BY ATTRITION STATUS")
plt.xlabel("ATTRITION STATUS")
plt.ylabel("MONTHLY INCOME")
plt.show()

# %% [markdown]
# Action Performed:
# - Used boxplot for MonthlyIncome vs Attrition.
#
# Outcome:
# - Shows distribution, outliers, and median income per attrition category.

# %% [markdown]
# STEP 4: ***MULTIVARIATE ANALYSIS – UNDERSTANDING DATA DISTRIBUTION***
#
# ```SUMMARY```
# - Analysis of three or more variables together to understand their relationships.
#
# Objective:
#
# - Identify patterns and relationships between multiple variables.
# - Understand how variables influence each other.

# %% [markdown]
#  Visual 12: Correlation Matrix - Heatmap (Seaborn)
#
# Objective:
# - Identify relationships among numeric variables.
#
# Action Performed:
# - Computed correlation matrix and plotted using heatmap.

# %%
num_cols = ['Age','MonthlyIncome','YearsAtCompany','JobSatisfaction','WorkLifeBalance']
corr = data[num_cols].corr()
plt.figure(figsize=(8,6))
sns.heatmap(corr, cmap='coolwarm', annot=True)
plt.title("CORRELATION HEATMAP (SELECTED VARIABLES)")
plt.show()

# %% [markdown]
# Action Performed:
# - Used boxplot for MonthlyIncome vs Attrition.
# Outcome:
# - Shows distribution, outliers, and median income per attrition category.

# %% [markdown]
# Outcome: Shows strong and weak correlations.

# %% [markdown]
# >Visual 13: Attrition Rate by Employee Source and Tenure Group - point plot
#
# Objective:
#
# - Analyze how attrition rate varies across employee sources and tenure groups.

# %%
plt.figure(figsize=(10,6))

sns.pointplot(data=data,x='Employee Source',y='AttritionFlag',hue='TenureGroup',estimator=np.mean,dodge=True)
plt.title("ATTRITION RATE BY EMPLOYEE SOURCE AND TENURE GROUP")
plt.ylabel("ATTRITION RATE")
plt.xlabel("EMPLOYEE SOURCE")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Action Performed:
#
# - Used a point plot to visualize mean attrition rate by employee source, segmented by tenure group.
#
# Outcome:
#
# - Clear differences in attrition rates are observed across sources and tenure durations.

# %% [markdown]
# >***STEP 5: GROUPBY ANALYSIS – UNDERSTANDING DATA DISTRIBUTION***
#
# Objective:
#
# - To analyze how numerical values (such as age and income) vary across different categories.
#
# ```Summary```
#
# - Groupby groups data by a category and applies calculations like mean or count. It helps compare values across groups and identify patterns easily.

# %% [markdown]
# > VISUAL 14: AVERAGE MONTHLY INCOME BY DEPARTMENT
# Objective:
# - To compare the average monthly income across different departments.

# %%
data.groupby('Department')['MonthlyIncome'].mean().plot(
    kind='bar',
    color='brown'
)
plt.title("AVERAGE MONTHLY INCOME BY DEPARTMENT")
plt.xlabel("DEPARTMENT")
plt.ylabel("AVERAGE MONTHLY INCOME")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# Action Performed:
#
# - Grouped the data by Department and calculated the mean of Monthly Income, then visualized the result using a bar chart.
#
# Outcome:
# - The chart shows the average salary level for each department.

# %% [markdown]
# >VISUAL 15: AVERAGE AGE BY ATTRITION STATUS
#
# Objective:
#
# - To understand the relationship between employee age and attrition.

# %%
data.groupby('Attrition')['Age'].mean().plot(
    kind='bar',
    color=['green', 'red']
)
plt.title("AVERAGE AGE BY ATTRITION STATUS")
plt.xlabel("ATTRITION STATUS")
plt.xticks(rotation=0)
plt.ylabel("AVERAGE AGE")
plt.show()

# %% [markdown]
# Action Performed:
#
# - Grouped employees by Attrition status and computed the average age, then plotted the values using a bar chart.
#
# Outcome:
#
# - The visualization compares the mean age of employees who stayed versus those who left.

# %% [markdown]
# >***STEP 6: PIVOT TABLE***
#
#
# Objective:
#
# - To summarize and compare data across multiple categories in a structured format.
#
# ```Summary:```
#
# - A pivot table organizes data into rows and columns and shows aggregated results. It is useful for analyzing relationships such as attrition across job roles.

# %% [markdown]
# VISUAL 16: ATTRITION BY JOB ROLE (Pivot Table)
#
# Objective:
#
# - To analyze attrition distribution across different job roles.

# %%
pivot = data.pivot_table(
    index='JobRole',
    columns='Attrition',
    aggfunc='size'
)

# %%
pivot.plot(kind='bar')

plt.title("ATTRITION BY JOB ROLE")
plt.xlabel("JOB ROLE")
plt.ylabel("EMPLOYEE COUNT")
plt.xticks(rotation=45)
plt.legend(title="ATTRITION STATUS")
plt.tight_layout()
plt.show()

# %% [markdown]
# Action Performed:
#
# - Created a pivot table grouping Job Role and Attrition status, counted employees, and visualized the result using a bar chart.
#
# Outcome:
#
# - The chart displays the number of employees who stayed and left in each job role.

# %% [markdown]
# ***Conclusion***:
#
# This analysis provides a comprehensive overview of employee attrition patterns within the organization using the HR Insights: Tracking Workforce Trends dataset. Through systematic exploratory data analysis, key insights were uncovered regarding demographic factors, job roles, compensation, work experience, and satisfaction levels that influence employee turnover.

# %% [markdown]
# <h1 style="font-size:22px;">PHASE 4: SUMMARY AND RECOMMENDATIONS.</h1>

# %% [markdown]
# <h2 style="font-size:20px;">4.1 Overall Findings Summary</h2>
#
# This comprehensive exploratory data analysis of the HR Insights: Tracking Workforce Trends Attrition dataset (23,530 employees) reveals an overall attrition rate of approximately 16%, highlighting that behavioral and workplace factors—not employee demographics—are the primary drivers of attrition.
#
# The analysis identified OverTime as the strongest predictor of employee exits, monthly income and job satisfaction as critical retention levers, and revealed important career lifecycle patterns where attrition risk is highest during early tenure stages.

# %% [markdown]
# ***Core Discoveries***
#
# `Primary Finding`
#
# Employee attrition is driven mainly by workload pressure, compensation dissatisfaction, and low job satisfaction, while demographic variables such as gender and department size show minimal direct impact on attrition.

# %% [markdown]
# ```Key Metrics```
#
# - Overall attrition rate: ~16%
#
# - OverTime impact: Employees working overtime show nearly double the attrition rate
#
# - Income effect: Lower income groups experience significantly higher attrition
#
# - Career stage risk: Highest attrition among early-tenure employees
#
# - Satisfaction impact: Attrition increases sharply at low job satisfaction levels

# %% [markdown]
# ```Most Surprising Findings```
#
# - Performance rating does not prevent attrition — high performers also leave
#
# - OverTime outweighs salary as an attrition trigger
#
# - Demographics have limited influence compared to behavioral factors
#
# - Correlation analysis alone underestimates workload effects
#
# - Early career exits represent the largest retention loss

# %% [markdown]
# **Top 5 Key Insights**

# %% [markdown]
# >***INSIGHT 1***: OverTime is the Strongest Attrition Driver
#
# `Finding:`
#
# - Employees working OverTime = Yes exhibit a significantly higher attrition rate
#
# - Indicates burnout, stress, and work–life imbalance
#
# - This pattern is consistent across departments and job roles, making overtime the most critical and actionable risk factor.
#
# `Strategic Action:`
#
# - Implement overtime controls, workload redistribution, and flexible scheduling policies.

# %% [markdown]
# >***INSIGHT 2***: Lower Monthly Income Increases Attrition Risk
#
# `Finding:`
#
# - Employees in lower income bands are more likely to leave
#
# - Attrition steadily decreases as monthly income increases
#
# - Compensation dissatisfaction pushes employees to seek better opportunities externally.
#
# `Strategic Action:`
# - Review salary structures for early-career and high-workload roles and align pay with market standards.

# %% [markdown]
# >***INSIGHT 3***: Job Satisfaction and Work-Life Balance Drive Retention
#
# `Finding:`
#
# - Employees with low job satisfaction and poor work-life balance show much higher attrition
#
# - High satisfaction strongly correlates with employee retention
#
# - This confirms that workplace culture and perceived workload directly affect employee commitment.
#
# `Strategic Action:`
#
# - Strengthen engagement programs, manager feedback quality, and work-life balance initiatives.

# %% [markdown]
# >***INSIGHT 4***: Attrition is Highest During Early Career Stages
#
# `Finding:`
#
# - Employees with short tenure and fewer total working years have higher attrition
#
# - Attrition decreases as employees gain experience and organizational stability
#
# - Early exits represent a major loss of recruitment and training investment.
#
# `Strategic Action:`
#
# - Enhance onboarding, mentoring, and first-year employee support programs.

# %% [markdown]
# >***INSIGHT 5***: Performance Rating Has Minimal Impact on Attrition
#
# `Finding:`
#
# - Most employees cluster around performance ratings of 3–4
#
# - Attrition occurs across all performance levels
#
# - High performers leaving indicates that attrition is not performance-driven, but workload- and satisfaction-driven.
#
# `Strategic Action:`
#
# - Shift retention focus from performance metrics to workload, engagement, and satisfaction indicators.

# %% [markdown]
# **Correlations & Patterns Observed**
#
# - Positive association: OverTime → Attrition
#
# - Negative association: Monthly Income, Job Satisfaction → Attrition
#
# - Weak demographic correlation: Gender and department-level attributes
#
# - Key takeaway: Linear correlation alone misses critical behavioral attrition patterns

# %% [markdown]
# <strong></strong>

# %% [markdown]
# <h2 style="font-size:20px;">4.2 Business Recommendations</h2>

# %% [markdown]
# ***Reduce OverTime to Prevent Burnout***
#
# >Target Segment: Employees working overtime
#
#    `Strategy:`
#
# - Monitor weekly working hours
#
# - Enforce workload redistribution
#
# - Promote flexible work arrangements
#
# `Expected Impact:`
#
# - Lower burnout-driven attrition
#
# - Improved employee well-being and productivity

# %% [markdown]
# ***Strengthen Early-Career Retention***
#
# >Target Segment: Employees with low tenure
#
# `Strategy:`
#
# - Structured onboarding programs
#
# - Mentorship and buddy systems
#
# - Clear career progression pathways
#
# `Expected Impact:`
#
# - Reduced early attrition
#
# - Higher long-term workforce stability

# %% [markdown]
# ***Review Compensation for High-Risk Roles***
#
# >Target Segment: Low-income, high-workload employees
#
# `Strategy:`
#
# - Market-aligned salary revisions
#
# - Performance and skill-based incentives
#
# `Expected Impact:`
#
# - Reduced compensation-related exits
#
# - Improved job satisfaction

# %% [markdown]
# ***Improve Job Satisfaction & Work-Life Balance***
#
# `Strategy:`
#
# - Conduct regular satisfaction surveys
#
# - Train managers on employee engagement
#
# - Promote realistic workload planning
#
# `Expected Impact:`
#
# - Higher engagement levels
#
# - Stronger organizational culture

# %% [markdown]
# <h1 style="font-size:20px ";>Final Thought</h1>
#
# *This analysis demonstrates that employee attrition is fundamentally a behavioral and workplace management issue—not a demographic one. By focusing on overtime control, fair compensation, early-career support, and job satisfaction, organizations can shift from reactive attrition management to proactive workforce retention.*
#
# *Understanding both WHAT drives attrition (workload, income, satisfaction) and WHEN it occurs (early career stages) provides a complete, evidence-based framework for reducing attrition and building a more stable, engaged workforce.*
